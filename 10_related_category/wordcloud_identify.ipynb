# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
folder_data = r"C:\Users\bputra\OneDrive - ESRI Indonesia\Data Services\data-item-attachment-nationalhub-arcgishub"
file_data = f"{folder_data}\\tracking_data_progress_scrapping.csv"
print(file_data)
# Out:
# C:\Users\bputra\OneDrive - ESRI Indonesia\Data Services\data-item-attachment-nationalhub-arcgishub\tracking_data_progress_scrapping.csv

# %%
data = pd.read_csv(file_data, delimiter=';')
df = pd.DataFrame(data)
df
# Out:
#         No                      BRAND  TAGS/0  \
# 0      1.0       Aston Martin (Mobil)  Retail
# 1      2.0               Audi (Mobil)  Retail
# 2      3.0            Bentley (Mobil)  Retail
# 3      4.0                BMW (Mobil)  Retail
# 4      5.0              Chery (Mobil)  Retail
# ..     ...                        ...     ...
# 429  429.0                  OYO Hotel     NaN
# 430  429.0  Trip Advisor - Attraction     NaN
# 431  432.0   Cagar Budaya - Kemdikbud     NaN
# 432  433.0              Kantor Polisi     NaN
# 433    NaN                        NaN     NaN
#
#                                                   TAGS  COUNT     SOURCE  \
# 0    Retail;Automotive Service;Auto Dealership;Auto...    1.0    Website
# 1    Retail;Automotive Service;Auto Dealership;Auto...    9.0    Website
# 2    Retail;Automotive Service;Auto Dealership;Auto...    1.0    Website
# 3    Retail;Automotive Service;Auto Dealership;Auto...   23.0    Website
# ...

# %%
field = 'BRAND'
all_text = ' '.join(data[field].dropna())

# Membuat WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Tampilkan WordCloud menggunakan Matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from collections import Counter

# Menghitung frekuensi kata-kata dalam teks
word_freq = Counter(all_text.split())

# Menampilkan kata-kata yang paling banyak muncul
most_common_words = word_freq.most_common(50)  # Mengambil 20 kata teratas
#print(most_common_words)

for word, freq in most_common_words:
    print(f"{word}: {freq}")
# Out:
# penginapan: 688
# di: 197
# murah: 128
# dekat: 112
# harga: 84
# terdekat: 54
# puncak: 43
# malioboro: 33
# hotel: 32
# pantai: 32
# view: 30
# bromo: 22
# ocean: 19
# sekitar: 17
# santolo: 17
# panjang: 17
# karang: 17
# resort: 17
# solo: 16
# heha: 16
# oyo: 15
# stasiun: 15
# villa: 14
# potong: 14
# syariah: 14
# gunung: 14
# batu: 12
# malang: 12
# saya: 12
# dari: 11
# lokasi: 11
# tempat: 11
# darajat: 11
# pass: 11
# bagus: 10
# ciletuh: 10
# sayang: 10
# heulang: 10
# yang: 10
# untuk: 9
# semilir: 9
# sini: 9
# bukit: 9
# dusun: 8
# bedugul: 8
# padang: 8
# 2022: 8
# sidebuk: 8
# debuk: 8
# siosar: 8
