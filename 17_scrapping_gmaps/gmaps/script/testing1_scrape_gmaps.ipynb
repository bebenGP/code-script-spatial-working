# %%
import pandas as pd
import csv
from selenium import webdriver
import time

# %%
data = r"C:\Users\bputra\OneDrive - ESRI Indonesia\PT ESRI Indonesia\Research\code-script\17_scrapping_gmaps\gmaps\input\kabkot_list_and_xy_sample.csv"
df = pd.read_csv(data, delimiter=";")
pd.DataFrame(df)
# Out:
#                                kakot  Shape_Leng  Shape_Area       lat  \
# 0  Kota Administrasi Jakarta Selatan    0.848568    0.011820 -6.272567
# 1                         Kota Bogor    0.708177    0.009106 -6.593494
# 2                        Kota Padang    1.881366    0.056664 -0.899532
# 3                           Magelang    2.016873    0.093674 -7.502515
# 4                            Pacitan    2.715767    0.117653 -8.124997
#
#          long
# 0  106.810043
# 1  106.799357
# 2  100.437912
# 3  110.249411
# 4  111.178150

# %%
#url = 'https://www.google.com/maps/search/Bulutangkis/@{},{},12.58z?entry=ttu' 
data_lat = df['lat']
data_long = df['long']

# %%
#driver = webdriver.Chrome(executable_path="D:\SCRIPT - ARCPY - PYTHON\scrapping\gmaps\script\chromedriver_win32\chromedriver.exe")

# %%
driver = webdriver.Chrome()
def url_hit(data_latitude, data_longitude) :
    for latitude, longitude in zip (data_latitude, data_longitude) :
        url = f'https://www.google.com/maps/search/Bulutangkis/@{latitude},{longitude},12.58z?entry=ttu' 
        #print(url)
        driver.get(url)
        time.sleep(3)
        
        # Scroll down sampai list lokasi bulutangkis habis terscroll
        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)  # Tunggu beberapa detik setelah scroll
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height
            
url_hit(data_lat, data_long)

driver.quit()

# %%
from selenium import webdriver
import time

# Inisialisasi WebDriver Chrome
driver = webdriver.Chrome()

def scroll_down_to_bottom(xpath):
    # Temukan elemen dengan XPath yang diberikan
    element = driver.find_elements("xpath",xpath)
    # Lakukan scroll hingga elemen terakhir terlihat
    driver.execute_script("arguments[0].scrollIntoView(true);", element)
    time.sleep(2)  # Tunggu beberapa detik setelah scroll

def url_hit(data_latitude, data_longitude):
    for latitude, longitude in zip(data_latitude, data_longitude):
        url = f'https://www.google.com/maps/search/Bulutangkis/@{latitude},{longitude},12.58z?entry=ttu'
        driver.get(url)
        time.sleep(3)  # Tunggu beberapa detik agar halaman terbuka sepenuhnya
        # Lakukan scroll down ke area dengan XPath yang diberikan
        scroll_down_to_bottom('//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]')

# Panggil fungsi untuk membuka URL dan melakukan scroll
url_hit(data_lat, data_long)

# Tutup WebDriver setelah selesai
driver.quit()

# %%
from selenium import webdriver
import time

# Inisialisasi WebDriver Chrome
driver = webdriver.Chrome()

def scroll_down_to_bottom(xpath):
    # Temukan elemen dengan XPath yang diberikan
    element = driver.find_element("xpath", xpath)
    # Lakukan scroll hingga elemen terakhir terlihat
    driver.execute_script("arguments[0].scrollIntoView(true);", element)
    time.sleep(2)  # Tunggu beberapa detik setelah scroll

def url_hit(data_latitude, data_longitude):
    for latitude, longitude in zip(data_latitude, data_longitude):
        url = f'https://www.google.com/maps/search/Bulutangkis/@{latitude},{longitude},12.58z?entry=ttu'
        driver.get(url)
        time.sleep(3)  # Tunggu beberapa detik agar halaman terbuka sepenuhnya
        # Lakukan scroll down ke area dengan XPath yang diberikan
        scroll_down_to_bottom('//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]')

# Panggil fungsi untuk membuka URL dan melakukan scroll
url_hit(data_lat, data_long)

# Tutup WebDriver setelah selesai
driver.quit()

# %%
from selenium import webdriver
import time

# Inisialisasi WebDriver Chrome
driver = webdriver.Chrome()

def scroll_down_to_bottom(xpath):
    # Temukan elemen dengan XPath yang diberikan
    element = driver.find_element("xpath", xpath)
    # Lakukan scroll hingga elemen terakhir terlihat
    driver.execute_script("arguments[0].scrollIntoView(true);", element)
    time.sleep(2)  # Tunggu beberapa detik setelah scroll

def scroll_down_until_end():
    SCROLL_PAUSE_TIME = 0.5

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

def url_hit(data_latitude, data_longitude):
    for latitude, longitude in zip(data_latitude, data_longitude):
        
        url = f'https://www.google.com/maps/search/Bulutangkis/@{latitude},{longitude},12.58z?entry=ttu'
        # ini link nya 
        #https://www.google.com/maps/search/pijat/@-6.231677,106.8244863,14z/data=!4m2!2m1!6e1?entry=ttu
        
        driver.get(url)
        time.sleep(3)  # Tunggu beberapa detik agar halaman terbuka sepenuhnya
        # Lakukan scroll down ke area dengan XPath yang diberikan
        scroll_down_to_bottom('//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]')
        # Lakukan scroll hingga akhir halaman
        scroll_down_until_end()

# Panggil fungsi untuk membuka URL dan melakukan scroll
url_hit(data_lat, data_long)

# Tutup WebDriver setelah selesai
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[7], line 45
#      42         scroll_down_until_end()
#      44 # Panggil fungsi untuk membuka URL dan melakukan scroll
# ---> 45 url_hit(data_lat, data_long)
#      47 # Tutup WebDriver setelah selesai
#      48 driver.quit()
#
# Cell In[7], line 40, in url_hit(data_latitude, data_longitude)
#      38 time.sleep(3)  # Tunggu beberapa detik agar halaman terbuka sepenuhnya
#      39 # Lakukan scroll down ke area dengan XPath yang diberikan
# ---> 40 scroll_down_to_bottom('//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]')
#      41 # Lakukan scroll hingga akhir halaman
#      42 scroll_down_until_end()
#
# Cell In[7], line 9, in scroll_down_to_bottom(xpath)
#       7 def scroll_down_to_bottom(xpath):
#       8     # Temukan elemen dengan XPath yang diberikan
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# Jalankan browser dan buka website
driver = webdriver.Chrome()
driver.get("https://www.google.com/maps/search/bulutangkis/@-6.2299749,106.8244864,14z?entry=ttu")

# Temukan element yang ingin di scroll
element = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]')

#driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
driver.execute_script("arguments[0].scrollIntoView(true);", element)

# Tunggu beberapa detik agar semua list informasi dimuat
time.sleep(5)

# Lakukan proses selanjutnya, seperti scraping data
# ...

# Tutup browser
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# Jalankan browser dan buka website
driver = webdriver.Chrome()
driver.get("https://www.google.com/maps/search/bulutangkis/@-6.2299749,106.8244864,14z?entry=ttu")

# Temukan element yang ingin di scroll
element = driver.find_element(By.CSS_SELECTOR, ".w6Uhzf > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1)")

# Scroll down dengan JavaScript
driver.execute_script("arguments[0].scrollIntoView(true);", element)

# Tunggu beberapa detik agar semua list informasi dimuat
time.sleep(5)

# Lakukan proses selanjutnya, seperti scraping data
# ...

# Tutup browser
driver.quit()

# %% [markdown]
# ### Action Chains

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

# Jalankan browser dan buka website
driver = webdriver.Chrome()
driver.get("https://www.google.com/maps/search/bulutangkis/@-6.2299749,106.8244864,14z?entry=ttu")

# Temukan element yang ingin di scroll
element = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]')

# Scroll down dengan Action Chains
actions = ActionChains(driver)
actions.move_to_element(element).perform()

# Tunggu beberapa detik agar semua list informasi dimuat
time.sleep(5)

# Lakukan proses selanjutnya, seperti scraping data
# ...

# Tutup browser
driver.quit()

# %% [markdown]
# ### Pixel Offser

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# Jalankan browser dan buka website
driver = webdriver.Chrome()
driver.get("https://www.google.com/maps/search/bulutangkis/@-6.2299749,106.8244864,14z?entry=ttu")

# Scroll down dengan pixel offset
for i in range(10):
    driver.execute_script("window.scrollBy(0, 500)")
    time.sleep(0.5)

# Tunggu beberapa detik agar semua list informasi dimuat
time.sleep(5)

# Lakukan proses selanjutnya, seperti scraping data
# ...

# Tutup browser
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time

driver = webdriver.Chrome()
url = "https://www.google.com/maps/search/pijat/@-6.231677,106.8244863,14z/data=!4m2!2m1!6e1?entry=ttu"
driver.get(url)

xpath_sidebar = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]')

def check_exists_by_xpath(xpath):
    try:
        driver.find_element(By.XPATH, xpath)
    except:
        return False
    return True

def scroll_to_bottom(iteration=None):
    if(iteration == None):
        driver.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", xpath_sidebar)
        time.sleep(2)
    else:
        for i in range(1, iteration):
            driver.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", xpath_sidebar)
            time.sleep(2)

for i in range(1, 100):
    # scroll down to bottom sidebar
    scroll_to_bottom()

    # xpath_endsidebar = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[243]/div/p/span/span')
    if(check_exists_by_xpath('/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[243]/div/p/span/span')):
        scroll_to_bottom(2)
        print("End!!")
        break

time.sleep(5)
driver.quit()
# Out:
# End!!
