# %% [markdown]
# ## Raw Schema Fixed

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException 
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from lxml import etree
import requests
import csv
import pandas as pd

# %%
url = 'https://www.google.com/maps/search/Bulutangkis/@-6.5934944,106.7993574,12z?entry=ttu'

# %%
options = Options()
options.headless = True
driver = webdriver.Chrome(options=options)

driver.get(url)

# Dapatkan HTML halaman web setelah di-render
html = driver.page_source

# Gunakan BeautifulSoup untuk mengekstrak data
soup = BeautifulSoup(html, 'lxml')

tes = soup.find_all('div', class_='bJzME tTVLSc')

for cari in tes:
    
    hrefs = cari.find_all('a', class_='hfpxzc')
    for href in hrefs:
        href_value = href.get('href')
        print(href_value)
                
    poi_names = cari.find_all('div', class_='qBF1Pd fontHeadlineSmall')
    for poi in poi_names:
        poinames_value = poi.text.strip() 
        print(poinames_value)
    
    ratings = cari.find_all('span', class_='MW4etd')
    for rating in ratings:
        ratings_value = rating.text.strip()
        print(ratings_value)
    
    
    address_schema = cari.find_all('div', class_='Nv2PK tH5CWc THOPZb')
    found_addresses = set()
    for address_testing in address_schema :                
        tagsaddress_elements = cari.find_all('div', class_='W4Efsd')
        for tagsaddress1 in tagsaddress_elements :
            tagsaddress1_value = tagsaddress1.find_all('div', class_='W4Efsd')
            for tagsaddress2 in tagsaddress1_value :
                tagsaddress2_value = tagsaddress2.findParents('div', class_='W4Efsd')
                for tagsaddress3 in tagsaddress2_value :
                    tagsaddress3_value = tagsaddress3.text.strip()
                    # Kondisi untuk memeriksa apakah alamat sudah ditemukan sebelumnya
                    if tagsaddress3_value not in found_addresses:
                        found_addresses.add(tagsaddress3_value)
                        
                        # Cetak alamat jika unik
                        print(tagsaddress3_value)
                        print('------')
driver.quit()
# Out:
# https://www.google.com/maps/place/GOR+88+BADMINTON+CIKARET/data=!4m7!3m6!1s0x2e69c1de3cd51be1:0x235bd6b89f83a018!8m2!3d-6.465987!4d106.84218!16s%2Fg%2F11c47_k7p7!19sChIJ4RvVPN7BaS4RGKCDn7jWWyM?authuser=0&hl=id&rclk=1
# https://www.google.com/maps/place/GOR+Badminton+Bukit+Jaya/data=!4m7!3m6!1s0x2e69c1d6c241b333:0x998ae456470861ab!8m2!3d-6.4643855!4d106.8569293!16s%2Fg%2F11c32b2c8n!19sChIJM7NBwtbBaS4Rq2EIR1bkipk?authuser=0&hl=id&rclk=1
# https://www.google.com/maps/place/Gor+Bulutangkis+Kosalina+%28Bang+Cepi%29/data=!4m7!3m6!1s0x2e69c314edb554f9:0xf716c8085a725ac4!8m2!3d-6.4919235!4d106.7998143!16s%2Fg%2F11f662kblv!19sChIJ-VS17RTDaS4RxFpyWgjIFvc?authuser=0&hl=id&rclk=1
# https://www.google.com/maps/place/GOR+BS/data=!4m7!3m6!1s0x2e69c5a86e1c467f:0x52c9236aa83c3ee3!8m2!3d-6.5635142!4d106.7889175!16s%2Fg%2F11gn258r7y!19sChIJf0YcbqjFaS4R4z48qGojyVI?authuser=0&hl=id&rclk=1
# Lapangan Bulutangkis · CQ86+3C7, Jl. Bougenville Jl. Sela Galih Ciomas RahayuBuka 24 jam
# ------
# Lapangan Bulutangkis · FQHH+42P, RT.03/RW.07Buka ⋅ Tutup pukul 00.00 · 0895-3553-55064
# ------
# Lapangan Bulutangkis · Jl. Al-Baliyah Jl. RE Sulaeman No.26Segera tutup ⋅ 23.00 ⋅ Buka Jum pukul 07.00 · 0896-3887-5685
# ------
# Klub Badminton · FP3H+WF7, Jl. Carang PulangBuka 24 jam · 0858-1051-0788
# ------
# Lapangan Bulutangkis · Jl. Sawojajar No.5, RT.01/RW.04Segera tutup ⋅ 23.00 ⋅ Buka Jum pukul 07.00 · (0251) 8326699
# ------

# %% [markdown]
# ## Testing Schema Saved Data

# %% [markdown]
# #### Testing Main Schema

# %%
import csv
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException 
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from lxml import etree
import requests

url = 'https://www.google.com/maps/search/Bulutangkis/@-6.5934944,106.7993574,12z?entry=ttu'

options = Options()
options.headless = True
driver = webdriver.Chrome(options=options)

driver.get(url)

# Dapatkan HTML halaman web setelah di-render
html = driver.page_source

# Gunakan BeautifulSoup untuk mengekstrak data
soup = BeautifulSoup(html, 'lxml')

tes = soup.find_all('div', class_='bJzME tTVLSc')

# Buat file CSV
with open('bulutangkis_places1.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Name', 'Rating', 'Address', 'URL']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for cari in tes:
        hrefs = cari.find_all('a', class_='hfpxzc')
        for href in hrefs:
            href_value = href.get('href')
                
        poi_names = cari.find_all('div', class_='qBF1Pd fontHeadlineSmall')
        for poi in poi_names:
            poinames_value = poi.text.strip() 
            print(poinames_value)
    
        ratings = cari.find_all('span', class_='MW4etd')
        for rating in ratings:
            ratings_value = rating.text.strip()
    
        address_schema = cari.find_all('div', class_='Nv2PK tH5CWc THOPZb')
        found_addresses = set()
        for address_testing in address_schema :                
            tagsaddress_elements = cari.find_all('div', class_='W4Efsd')
            for tagsaddress1 in tagsaddress_elements :
                tagsaddress1_value = tagsaddress1.find_all('div', class_='W4Efsd')
                for tagsaddress2 in tagsaddress1_value :
                    tagsaddress2_value = tagsaddress2.findParents('div', class_='W4Efsd')
                    for tagsaddress3 in tagsaddress2_value :
                        tagsaddress3_value = tagsaddress3.text.strip()
                        # Kondisi untuk memeriksa apakah alamat sudah ditemukan sebelumnya
                        if tagsaddress3_value not in found_addresses:
                            found_addresses.add(tagsaddress3_value)
                            
                            # Tulis data ke dalam file CSV
                            writer.writerow({'Name': poinames_value, 'Rating': ratings_value, 'Address': tagsaddress3_value, 'URL': href_value})

driver.quit()
# Out:
# GOR 88 BADMINTON CIKARET
# GOR Badminton Bukit Jaya
# Hall Bulutangkis Pb Batara
# GOR Bulutangkis KAYPI
# Gor Bulutangkis Kosalina (Bang Cepi)
# Bulutangkis Melia Sawojajar
# Bintang Badminton Club
# GOR Bulutangkis Taman Yasmin Bogor
# GOR BS
# Hall Bulutangkis INDRAPRASTA

# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException 
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from lxml import etree
import requests

url = 'https://www.google.com/maps/search/Bulutangkis/@-6.5934944,106.7993574,12z?entry=ttu'

options = Options()
options.headless = True
driver = webdriver.Chrome(options=options)

driver.get(url)

# Dapatkan HTML halaman web setelah di-render
html = driver.page_source

# Gunakan BeautifulSoup untuk mengekstrak data
soup = BeautifulSoup(html, 'lxml')

tes = soup.find_all('div', class_='bJzME tTVLSc')

# Membuat list kosong untuk menyimpan data
data = []

for cari in tes:
    hrefs = cari.find_all('a', class_='hfpxzc')
    for href in hrefs:
        href_value = href.get('href')
                
    poi_names = cari.find_all('div', class_='qBF1Pd fontHeadlineSmall')
    for poi in poi_names:
        poinames_value = poi.text.strip() 
    
    ratings = cari.find_all('span', class_='MW4etd')
    for rating in ratings:
        ratings_value = rating.text.strip()
    
    address_schema = cari.find_all('div', class_='Nv2PK tH5CWc THOPZb')
    found_addresses = set()
    for address_testing in address_schema :                
        tagsaddress_elements = cari.find_all('div', class_='W4Efsd')
        for tagsaddress1 in tagsaddress_elements :
            tagsaddress1_value = tagsaddress1.find_all('div', class_='W4Efsd')
            for tagsaddress2 in tagsaddress1_value :
                tagsaddress2_value = tagsaddress2.findParents('div', class_='W4Efsd')
                for tagsaddress3 in tagsaddress2_value :
                    tagsaddress3_value = tagsaddress3.text.strip()
                    # Kondisi untuk memeriksa apakah alamat sudah ditemukan sebelumnya
                    if tagsaddress3_value not in found_addresses:
                        found_addresses.add(tagsaddress3_value)
                        
                        # Menambahkan data ke list
data.append({'Name': poinames_value, 'Rating': ratings_value, 'Address': tagsaddress3_value, 'URL': href_value})

driver.quit()

# Membuat DataFrame dari list data
df = pd.DataFrame(data)

# Menyimpan DataFrame ke dalam file CSV
df.to_csv('bulutangkis_places4.csv', index=False, encoding='utf-8-sig', sep=';')

# %% [markdown]
# #### Testing 1

# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException 
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from lxml import etree
import requests

url = 'https://www.google.com/maps/search/Bulutangkis/@-6.5934944,106.7993574,12z?entry=ttu'

options = Options()
options.headless = True
driver = webdriver.Chrome(options=options)

driver.get(url)

# Dapatkan HTML halaman web setelah di-render
html = driver.page_source

# Gunakan BeautifulSoup untuk mengekstrak data
soup = BeautifulSoup(html, 'lxml')

tes = soup.find_all('div', class_='bJzME tTVLSc')

# Membuat list kosong untuk menyimpan data
data = []

for cari in tes:
    hrefs = cari.find_all('a', class_='hfpxzc')
    for href in hrefs:
        href_value = href.get('href')
        data.append({'URL': href_value})
        
    poi_names = cari.find_all('div', class_='qBF1Pd fontHeadlineSmall')
    for poi in poi_names:
        poinames_value = poi.text.strip() 
        data.append({'Name': poinames_value})
        
    ratings = cari.find_all('span', class_='MW4etd')
    for rating in ratings:
        ratings_value = rating.text.strip()
        data.append({'Rating': ratings_value})
        
    address_schema = cari.find_all('div', class_='Nv2PK tH5CWc THOPZb')
    found_addresses = set()
    for address_testing in address_schema :                
        tagsaddress_elements = cari.find_all('div', class_='W4Efsd')
        for tagsaddress1 in tagsaddress_elements :
            tagsaddress1_value = tagsaddress1.find_all('div', class_='W4Efsd')
            for tagsaddress2 in tagsaddress1_value :
                tagsaddress2_value = tagsaddress2.findParents('div', class_='W4Efsd')
# Out:
#                                                  URL Name Rating Address
# 0  https://www.google.com/maps/place/GOR+88+BADMI...  NaN    NaN     NaN
# 1  https://www.google.com/maps/place/Lapangan+Bul...  NaN    NaN     NaN
# 2  https://www.google.com/maps/place/GOR+Badminto...  NaN    NaN     NaN
# 3  https://www.google.com/maps/place/GOR+Bulutang...  NaN    NaN     NaN
# 4  https://www.google.com/maps/place/GOR+Bulutang...  NaN    NaN     NaN

# %%
df.to_csv('data11.csv',index=False, encoding='utf-8-sig',sep=';')

# %% [markdown]
# #### Testing 2

# %%
def check_exists_by_xpath(xpath):
    try:
        driver.find_element(By.XPATH, xpath)
    except:
        return False
    return True


def scroll_to_bottom(iteration=None):
    xpath_sidebar = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]')
    if(iteration == None):
        driver.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", xpath_sidebar)
        time.sleep(2)
    else:
        for i in range(1, iteration):
            driver.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", xpath_sidebar)
            time.sleep(2)
            
def crawling_data(tes) :
    # Gunakan BeautifulSoup untuk mengekstrak data
    # Membuat list kosong untuk menyimpan data
    data = []

    for cari in tes:
        hrefs = cari.find_all('a', class_='hfpxzc')
        for href in hrefs:
            href_value = href.get('href')
            data.append({'URL': href_value})
            
        poi_names = cari.find_all('div', class_='qBF1Pd fontHeadlineSmall')
        for poi in poi_names:
            poinames_value = poi.text.strip() 
            data.append({'Name': poinames_value})
            
        ratings = cari.find_all('span', class_='MW4etd')
        for rating in ratings:
            ratings_value = rating.text.strip()
            data.append({'Rating': ratings_value})
            
        address_schema = cari.find_all('div', class_='Nv2PK tH5CWc THOPZb')
        found_addresses = set()
        for address_testing in address_schema :                
            tagsaddress_elements = cari.find_all('div', class_='W4Efsd')
            for tagsaddress1 in tagsaddress_elements :
                tagsaddress1_value = tagsaddress1.find_all('div', class_='W4Efsd')
                for tagsaddress2 in tagsaddress1_value :
                    tagsaddress2_value = tagsaddress2.findParents('div', class_='W4Efsd')
                    for tagsaddress3 in tagsaddress2_value :
                        tagsaddress3_value = tagsaddress3.text.strip()
                        # Kondisi untuk memeriksa apakah alamat sudah ditemukan sebelumnya
                        if tagsaddress3_value not in found_addresses:
                            found_addresses.add(tagsaddress3_value)
                            data.append({'Address': tagsaddress3_value})   
                            #data.append({'Name': poinames_value, 'Rating': ratings_value, 'Address': tagsaddress3_value, 'URL': href_value})
                            #data.append({'URL': href_value, 'Name': poinames_value, 'Rating': ratings_value, 'Address': tagsaddress3_value})   
    print(data)
    df = pd.DataFrame(data, columns=['URL','Name', 'Rating', 'Address'])
    df.to_csv('data13.csv',index=False, encoding='utf-8-sig',sep=';')

# %%
def check_exists_by_xpath(xpath):
    try:
        driver.find_element(By.XPATH, xpath)
    except:
        return False
    return True


def scroll_to_bottom(iteration=None):
    xpath_sidebar = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]')
    if(iteration == None):
        driver.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", xpath_sidebar)
        time.sleep(2)
    else:
        for i in range(1, iteration):
            driver.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", xpath_sidebar)
            time.sleep(2)

def url_hit(data_latitude, data_longitude) :
    try : 
        for latitude, longitude in zip (data_latitude, data_longitude) :
            start_time = time.time()
            try : 
                url = f'https://www.google.com/maps/search/Bulutangkis/@{latitude},{longitude},12.58z?entry=ttu' 
                print(f"Start in {url}")
                driver.get(url)

                time.sleep(2)
                
                try :
                    for i in range(1, 100):
                        # scroll down to bottom sidebar
                        scroll_to_bottom()
                        
                        # xpath_endsidebar = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[243]/div/p/span/span')
                        if(check_exists_by_xpath('/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[243]/div/p/span/span')):
                            scroll_to_bottom(2)
                            print("End scroll down !!")
                            try :
                                # Dapatkan HTML halaman web setelah di-render
                                html = driver.page_source
                                # Gunakan BeautifulSoup untuk mengekstrak data
                                soup = BeautifulSoup(html, 'lxml')
                                tes = soup.find_all('div', class_='bJzME tTVLSc')
                                #start crawling data !
                                #crawling_data(tes)
                                data = []
                                for cari in tes:
                                    hrefs = cari.find_all('a', class_='hfpxzc')
                                    for href in hrefs:
                                        href_value = href.get('href')
                                        data.append({'URL': href_value})
                                        
                                    poi_names = cari.find_all('div', class_='qBF1Pd fontHeadlineSmall')
                                    for poi in poi_names:
                                        poinames_value = poi.text.strip() 
                                        data.append({'Name': poinames_value})
                                        print(poinames_value)
                                    ratings = cari.find_all('span', class_='MW4etd')
                                    for rating in ratings:
                                        ratings_value = rating.text.strip()
                                        data.append({'Rating': ratings_value})
                                        
                                    address_schema = cari.find_all('div', class_='Nv2PK tH5CWc THOPZb')
                                    found_addresses = set()
                                    for address_testing in address_schema :                
                                        tagsaddress_elements = cari.find_all('div', class_='W4Efsd')
                                        for tagsaddress1 in tagsaddress_elements :
                                            tagsaddress1_value = tagsaddress1.find_all('div', class_='W4Efsd')
                                            for tagsaddress2 in tagsaddress1_value :
                                                tagsaddress2_value = tagsaddress2.findParents('div', class_='W4Efsd')
                                                for tagsaddress3 in tagsaddress2_value :
                                                    tagsaddress3_value = tagsaddress3.text.strip()
                                                    # Kondisi untuk memeriksa apakah alamat sudah ditemukan sebelumnya
                                                    if tagsaddress3_value not in found_addresses:
                                                        found_addresses.add(tagsaddress3_value)
                                                        data.append({'Address': tagsaddress3_value}) 
                                                            #print('nanti disini lokasi logic scrapenya !')
                                    #data.append({'Name': poinames_value, 'Rating': ratings_value, 'Address': tagsaddress3_value, 'URL': href_value})
                                df = pd.DataFrame(data, columns=['URL','Name', 'Rating', 'Address'])
                                df.head()
                                print(df)
                                df.to_csv('data16.csv',index=False, encoding='utf-8-sig',sep=';')      
                            except Exception as e :
                                print("Terdapat error dibagian Crawling data(Function scrape_data)")
                            break
                
                except Exception as e :
                    print(f"Ada error ni di request {url} -> {e}")
                    
                print(f'url {url} sudah selesai load')
                


                
            except TimeoutError :
                print(f'Teeett habis waktu jadi error di {url}')
                
            end_time = time.time()
            
            execution_time = (end_time - start_time)/60
            print(f"Waktu yang dibutuhkan {execution_time:.2f} menit")
        
        print("Data sudah selesai di scrapping, horee !!!")
    
    except Exception as e :
        print('error nih haduhhh')

# %%
#data = r"D:\SCRIPT - ARCPY - PYTHON\script-python-working-in-esri\17_scrapping_gmaps\gmaps\input\kabkot_list_and_xy_sample.csv"
