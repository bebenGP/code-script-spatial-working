# %% [markdown]
# ## Extract

# %%
import pandas as pd
import csv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time

# %%
data = r"C:\Users\bputra\OneDrive - ESRI Indonesia\PT ESRI Indonesia\Research\code-script\17_scrapping_gmaps\gmaps\input\kabkot_list_and_xy_sample.csv"
df = pd.read_csv(data, delimiter=";")
pd.DataFrame(df)
# Out:
#                                kakot  Shape_Leng  Shape_Area       lat  \
# 0  Kota Administrasi Jakarta Selatan    0.848568    0.011820 -6.272567
# 1                         Kota Bogor    0.708177    0.009106 -6.593494
# 2                        Kota Padang    1.881366    0.056664 -0.899532
# 3                           Magelang    2.016873    0.093674 -7.502515
# 4                            Pacitan    2.715767    0.117653 -8.124997
#
#          long
# 0  106.810043
# 1  106.799357
# 2  100.437912
# 3  110.249411
# 4  111.178150

# %%
data_lat = df['lat']
data_long = df['long']

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
def check_exists_by_xpath(xpath):
    try:
        driver.find_element(By.XPATH, xpath)
    except:
        return False
    return True


def scroll_to_bottom(iteration=None):
    xpath_sidebar = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]')
    if(iteration == None):
        driver.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", xpath_sidebar)
        time.sleep(2)
    else:
        for i in range(1, iteration):
            driver.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", xpath_sidebar)
            time.sleep(2)
            
            
def url_hit(data_latitude, data_longitude) :
    try : 
        for latitude, longitude in zip (data_latitude, data_longitude) :
            start_time = time.time()
            try : 
                url = f'https://www.google.com/maps/search/Bulutangkis/@{latitude},{longitude},12.58z?entry=ttu' 
                #print(url)
                driver.get(url)
                time.sleep(2)
                
                try :
                    for i in range(1, 100):
                        # scroll down to bottom sidebar
                        scroll_to_bottom()

                        # xpath_endsidebar = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[243]/div/p/span/span')
                        if(check_exists_by_xpath('/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[243]/div/p/span/span')):
                            scroll_to_bottom(2)
                            print("End!!")
                            break
                
                except Exception as e :
                    print(f"Ada error ni di request {url} -> {e}")
                    
                print(f'url {url} sudah selesai load')
                
            except TimeoutError :
                print(f'Teeett habis waktu jadi error di {url}')
                
            end_time = time.time()
            
            execution_time = (end_time - start_time)/60
            print(f"Waktu yang dibutuhkan {execution_time:.2f} menit")
            
    except Exception as e :
        print('error nih haduhhh')
#---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#

# %%
driver = webdriver.Chrome()
url_hit(data_lat, data_long)
time.sleep(5)
driver.quit()

# %%
driver = webdriver.Chrome()
def scrape_data() :
    #list element
    xpath_url =     '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/a'
    xpath_poi =     '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[1]/div[2]'
    xpath_rating =  '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[3]/div/span[2]/span/span[1]'
    xpath_tags =    '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[1]/span'
    xpath_address = '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[2]/span[2]'
    xpath_phone =   '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[2]/span[2]/span[2]'
    
    #simpan data pertiap element
    all_data = []
    
    #mengatasi element dinamis
    for i in range(3, 12, 2) :
        xpath = xpath_url.format(i), xpath_poi.format(i), xpath_rating.format(i), xpath_tags.format(i), xpath_address.format(i), xpath_phone.format(i)
        elements = driver.find_elements(By.XPATH,xpath)
        for element in elements :
            information = element.text
            all_data.append(information)
            
    for info in all_data :
        print(info)
        
driver.quit()

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# Inisialisasi WebDriver Chrome
driver = webdriver.Chrome()

def scrape_data():
    # Daftar XPath untuk setiap informasi
    xpath_urls = [
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/a',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[1]/div[2]',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[3]/div/span[2]/span/span[1]',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[1]/span',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[2]/span[2]',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[2]/span[2]/span[2]'
    ]
    
    # List untuk menyimpan semua data
    all_data = []

    # Loop untuk mengekstrak informasi dari setiap elemen
    for i in range(3, 12, 2):  # misalnya, untuk nomor 3, 5, 7, 9, 11
        for xpath in xpath_urls:
            xpath = xpath.format(i)
            #print(xpath)
            try:
                element = driver.find_element(By.XPATH, xpath)
                information = element.text
                all_data.append(information)
            except NoSuchElementException:
                # Jika elemen tidak ditemukan, tambahkan string kosong ke dalam list
                all_data.append('')

    # Cetak semua data yang telah diambil
    for info in all_data:
        print(info)

# URL target
url = "https://www.google.com/maps/search/bulutangkis/@-6.1712823,106.783929,14z?authuser=0&entry=ttu"
driver.get(url)

# Panggil fungsi scrape_data untuk mengeksekusi scraping
scrape_data()

# Tutup WebDriver setelah selesai
driver.quit()
# Out:
# Lapangan Bulutangkis PB.KOBSEL
# 5,0
# Lapangan Bulutangkis
# Jl.Masjid Al-Hayah No.RT06/04 7, RT.7/RW.4
#
#
# GOR Badminton PB. Samudra
# 4,4
# Lapangan Bulutangkis
# 3, Jl. Angke Jaya 7 No.9, RT.2/RW.7
# 0818-0878-2252
#
# Lapangan Badminton Bang Jay
# 4,5
# Lapangan Bulutangkis
# Jl. Kerajinan No.19, RT.15/RW.8
# 0878-8124-4816
#
# Lapangan Bulutangkis Sampoerna
# 4,4
# Lapangan Bulutangkis
# Jl. Arwana I No.7, RT.13/RW.13
# 0856-9194-8530
#
# PB Talenta
# 4,4
# Lapangan Bulutangkis
# 1, PB talenta, RT.1/RW.6

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# Inisialisasi WebDriver Chrome
driver = webdriver.Chrome()

def scrape_data():
    # Daftar XPath untuk setiap informasi
    xpath_urls = [
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/a',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[1]/div[2]',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[3]/div/span[2]/span/span[1]',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[1]/span',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[2]/span[2]',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[2]/span[2]/span[2]'
    ]
    xpath_href = ['/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/a']
    
    # List untuk menyimpan semua data
    all_data = []

    # Loop untuk mengekstrak informasi dari setiap elemen
    for i in range(3, 12, 2):  # misalnya, untuk nomor 3, 5, 7, 9, 11
        for xpath,href_xpath in zip (xpath_urls, xpath_href) :
            xpath = xpath.format(i)
            href_xpath = href_xpath.format(i)
            print(xpath)
            try:
                element_data = driver.find_element(By.XPATH, xpath)
                element_href = driver.find_element(By.XPATH, href_xpath)
                
                information_data = element_data.text
                information_href = element_href.get_attribute('href')
                
                print(information_data)
                #print(information_href)
                
                all_data.append(information_data)
                #all_data.append((information_href, information_data))
            except NoSuchElementException:
                # Jika elemen tidak ditemukan, tambahkan string kosong ke dalam list
                all_data.append('')

    # Cetak semua data yang telah diambil
    for info in all_data:
        print(info)

# URL target
url = "https://www.google.com/maps/search/bulutangkis/@-6.1712823,106.783929,14z?authuser=0&entry=ttu"
driver.get(url)

# Panggil fungsi scrape_data untuk mengeksekusi scraping
scrape_data()

# Tutup WebDriver setelah selesai
driver.quit()
# Out:
# /html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[3]/div/a
#
# /html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[5]/div/a
#
# /html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[7]/div/a
#
# /html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[9]/div/a
#
# /html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[11]/div/a

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# Inisialisasi WebDriver Chrome
driver = webdriver.Chrome()

def scrape_data():
    # Daftar XPath untuk setiap informasi
    xpath_urls = [
        '//a[@class="hfpxzc"]'
    ]
    
    # List untuk menyimpan semua data
    all_data = []

    # Loop untuk mengekstrak informasi dari setiap elemen
    for xpath in xpath_urls:
        try:
            elements = driver.find_elements(By.XPATH, xpath)
            for element in elements:
                information_href = element.get_attribute('href')
                information_data = element.get_attribute('aria-label')
                all_data.append((information_href, information_data))
        except NoSuchElementException:
            # Jika elemen tidak ditemukan, tambahkan string kosong ke dalam list
            all_data.append(('',''))

    # Cetak semua data yang telah diambil
    for href, info in all_data:
        print(href, info)

# URL target
url = "https://www.google.com/maps/search/bulutangkis/@-6.1712823,106.783929,14z?authuser=0&entry=ttu"
driver.get(url)

# Panggil fungsi scrape_data untuk mengeksekusi scraping
scrape_data()

# Tutup WebDriver setelah selesai
driver.quit()
# Out:
# https://www.google.com/maps/place/Diaz+Badminton+Hall/data=!4m7!3m6!1s0x2e69f6910123ea9d:0x258d5c895a5c266d!8m2!3d-6.1900129!4d106.8026939!16s%2Fg%2F11b6cls0p1!19sChIJneojAZH2aS4RbSZcWolcjSU?authuser=0&hl=id&rclk=1 Diaz Badminton Hall
# https://www.google.com/maps/place/Hall+Parahyangan+Jatibaru/data=!4m7!3m6!1s0x2e69f68157f0066f:0x1202d51218b592f0!8m2!3d-6.1818712!4d106.8126319!16s%2Fg%2F11c2l0jpdj!19sChIJbwbwV4H2aS4R8JK1GBLVAhI?authuser=0&hl=id&rclk=1 Hall Parahyangan Jatibaru
# https://www.google.com/maps/place/Lapangan+Bulutangkis+PB.KOBSEL/data=!4m7!3m6!1s0x2e69f6855f544d6d:0xbc69fe80da23b821!8m2!3d-6.1862713!4d106.8060483!16s%2Fg%2F11dyyz2n75!19sChIJbU1UX4X2aS4RIbgj2oD-abw?authuser=0&hl=id&rclk=1 Lapangan Bulutangkis PB.KOBSEL
# https://www.google.com/maps/place/Lapangan+Badminton+Tomang/data=!4m7!3m6!1s0x2e69f7b20dff6853:0x68316f6bdb54abf5!8m2!3d-6.177224!4d106.7993413!16s%2Fg%2F11h3_fzw9j!19sChIJU2j_DbL3aS4R9atU22tvMWg?authuser=0&hl=id&rclk=1 Lapangan Badminton Tomang
# https://www.google.com/maps/place/Hall+Putera+Badminton/data=!4m7!3m6!1s0x2e69f6b8c95ac357:0xd8418c54da04d402!8m2!3d-6.2038952!4d106.7962477!16s%2Fg%2F11bzsf7s_b!19sChIJV8Naybj2aS4RAtQE2lSMQdg?authuser=0&hl=id&rclk=1 Hall Putera Badminton
# https://www.google.com/maps/place/Lapangan+Bulu+Tangkis+Patra/data=!4m7!3m6!1s0x2e69f6f894788605:0xf3ca301eceeb1c07!8m2!3d-6.1790323!4d106.7783634!16s%2Fg%2F11dyqxr13f!19sChIJBYZ4lPj2aS4RBxzrzh4wyvM?authuser=0&hl=id&rclk=1 Lapangan Bulu Tangkis Patra
# https://www.google.com/maps/place/PB+Talenta/data=!4m7!3m6!1s0x2e69f68f46eac4f7:0x661115a9e425238d!8m2!3d-6.1832722!4d106.805117!16s%2Fg%2F11f_bzp77x!19sChIJ98TqRo_2aS4RjSMl5KkVEWY?authuser=0&hl=id&rclk=1 PB Talenta
# https://www.google.com/maps/place/Lapangan+Bulutangkis/data=!4m7!3m6!1s0x2e69f71dfb341a19:0xacdae0ff350ea825!8m2!3d-6.1821582!4d106.8150875!16s%2Fg%2F11kmnz352g!19sChIJGRo0-x33aS4RJagONf_g2qw?authuser=0&hl=id&rclk=1 Lapangan Bulutangkis
# https://www.google.com/maps/place/GOR+Handayani+Kemanggisan/data=!4m7!3m6!1s0x2e69f6f2716508a9:0x54a988a2c33fb1b4!8m2!3d-6.18728!4d106.7903282!16s%2Fg%2F11bx9q4xh6!19sChIJqQhlcfL2aS4RtLE_w6KIqVQ?authuser=0&hl=id&rclk=1 GOR Handayani Kemanggisan
# https://www.google.com/maps/place/Lapangan+Bulu+Tangkis/data=!4m7!3m6!1s0x2e69f7aacdcf1b19:0xb0ce6ffee0f190fe!8m2!3d-6.1852599!4d106.8132887!16s%2Fg%2F11ny29wzyt!19sChIJGRvPzar3aS4R_pDx4P5vzrA?authuser=0&hl=id&rclk=1 Lapangan Bulu Tangkis

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# Inisialisasi WebDriver Chrome
driver = webdriver.Chrome()

def scrape_data():
    # Daftar XPath untuk setiap informasi
    xpath_urls = [
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/a',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[1]/div[2]',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[3]/div/span[2]/span/span[1]',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[1]/span',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[2]/span[2]',
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[2]/span[2]/span[2]' 
    ]
    
    # List untuk menyimpan semua data
    all_data = []

    # Loop untuk mengekstrak informasi dari setiap elemen
    for i in range(3, 12, 2):  # misalnya, untuk nomor 3, 5, 7, 9, 11
        for xpath in xpath_urls:
            xpath = xpath.format(i)
            try:
                if xpath.endswith('/@href'):  # jika XPath adalah untuk href
                    element = driver.find_element(By.XPATH, xpath)
                    information = element.get_attribute('href')  # ambil nilai href
                    all_data.append(information)
                else:
                    element = driver.find_element(By.XPATH, xpath)
                    information = element.text
                    all_data.append(information)
            except NoSuchElementException:
                # Jika elemen tidak ditemukan, tambahkan string kosong ke dalam list
                all_data.append('')

    # Cetak semua data yang telah diambil
    for info in all_data:
        print(info)

# URL target
url = "https://www.google.com/maps/search/bulutangkis/@-6.1712823,106.783929,14z?authuser=0&entry=ttu"
driver.get(url)

# Panggil fungsi scrape_data untuk mengeksekusi scraping
scrape_data()

# Tutup WebDriver setelah selesai
driver.quit()
# Out:
# https://www.google.com/maps/place/Diaz+Badminton+Hall/data=!4m7!3m6!1s0x2e69f6910123ea9d:0x258d5c895a5c266d!8m2!3d-6.1900129!4d106.8026939!16s%2Fg%2F11b6cls0p1!19sChIJneojAZH2aS4RbSZcWolcjSU?authuser=0&hl=id&rclk=1
# None
# None
# None
# None
# None
# https://www.google.com/maps/place/Hall+Parahyangan+Jatibaru/data=!4m7!3m6!1s0x2e69f68157f0066f:0x1202d51218b592f0!8m2!3d-6.1818712!4d106.8126319!16s%2Fg%2F11c2l0jpdj!19sChIJbwbwV4H2aS4R8JK1GBLVAhI?authuser=0&hl=id&rclk=1
# None
# None
# None
# None
#
# https://www.google.com/maps/place/Lapangan+Bulutangkis+PB.KOBSEL/data=!4m7!3m6!1s0x2e69f6855f544d6d:0xbc69fe80da23b821!8m2!3d-6.1862713!4d106.8060483!16s%2Fg%2F11dyyz2n75!19sChIJbU1UX4X2aS4RIbgj2oD-abw?authuser=0&hl=id&rclk=1
# None
# None
# None
# None
#
# https://www.google.com/maps/place/Lapangan+Badminton+Tomang/data=!4m7!3m6!1s0x2e69f7b20dff6853:0x68316f6bdb54abf5!8m2!3d-6.177224!4d106.7993413!16s%2Fg%2F11h3_fzw9j!19sChIJU2j_DbL3aS4R9atU22tvMWg?authuser=0&hl=id&rclk=1
# None
# None
# None
# None
# None
# https://www.google.com/maps/place/Hall+Putera+Badminton/data=!4m7!3m6!1s0x2e69f6b8c95ac357:0xd8418c54da04d402!8m2!3d-6.2038952!4d106.7962477!16s%2Fg%2F11bzsf7s_b!19sChIJV8Naybj2aS4RAtQE2lSMQdg?authuser=0&hl=id&rclk=1
# None
# None
# None
# None

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# Inisialisasi WebDriver Chrome
driver = webdriver.Chrome()

def scrape_data():
    # Daftar XPath untuk setiap informasi
    xpath_urls = [
        '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[{}]/div/a'
    ]
    
    # List untuk menyimpan semua href
    all_hrefs = []

    # Loop untuk mengekstrak informasi dari setiap elemen
    for i in range(3, 12, 2):  # misalnya, untuk nomor 3, 5, 7, 9, 11
        for xpath in xpath_urls:
            xpath = xpath.format(i)
            try:
                element = driver.find_element(By.XPATH, xpath)
                href = element.get_attribute('href')
                all_hrefs.append(href)
            except NoSuchElementException:
                all_hrefs.append('')

    # Cetak semua href yang telah diambil
    for href in all_hrefs:
        print(href)

# URL target
url = "https://www.google.com/maps/search/bulutangkis/@-6.1712823,106.783929,14z?authuser=0&entry=ttu"
driver.get(url)

# Panggil fungsi scrape_data untuk mengeksekusi scraping
scrape_data()

# Tutup WebDriver setelah selesai
driver.quit()
# Out:
# https://www.google.com/maps/place/Lapangan+Bulutangkis+PB.KOBSEL/data=!4m7!3m6!1s0x2e69f6855f544d6d:0xbc69fe80da23b821!8m2!3d-6.1862713!4d106.8060483!16s%2Fg%2F11dyyz2n75!19sChIJbU1UX4X2aS4RIbgj2oD-abw?authuser=0&hl=id&rclk=1
# https://www.google.com/maps/place/PB+Talenta/data=!4m7!3m6!1s0x2e69f68f46eac4f7:0x661115a9e425238d!8m2!3d-6.1832722!4d106.805117!16s%2Fg%2F11f_bzp77x!19sChIJ98TqRo_2aS4RjSMl5KkVEWY?authuser=0&hl=id&rclk=1
# https://www.google.com/maps/place/GOR+Badminton+PB.+Samudra/data=!4m7!3m6!1s0x2e69f6186b2e5c6b:0x5ed52ab301c3521b!8m2!3d-6.1456078!4d106.7955793!16s%2Fg%2F11c72xfvcb!19sChIJa1wuaxj2aS4RG1LDAbMq1V4?authuser=0&hl=id&rclk=1
# https://www.google.com/maps/place/Lapangan+Badminton+Bang+Jay/data=!4m7!3m6!1s0x2e69f60a5ba722d3:0x55d03adaf816ad38!8m2!3d-6.1533629!4d106.8157432!16s%2Fg%2F11c1tz36xh!19sChIJ0yKnWwr2aS4ROK0W-No60FU?authuser=0&hl=id&rclk=1
# https://www.google.com/maps/place/Lapangan+Bulutangkis+Sampoerna/data=!4m7!3m6!1s0x2e69f61f59751d29:0x71b668a708ae14b0!8m2!3d-6.1408544!4d106.7945255!16s%2Fg%2F11c0py6hxq!19sChIJKR11WR_2aS4RsBSuCKdotnE?authuser=0&hl=id&rclk=1

# %%
scrape_data()
# Out:
# ('/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[3]/div/a', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[3]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[1]/div[2]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[3]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[3]/div/span[2]/span/span[1]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[3]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[1]/span', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[3]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[2]/span[2]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[3]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[2]/span[2]/span[2]')
# ('/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[5]/div/a', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[5]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[1]/div[2]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[5]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[3]/div/span[2]/span/span[1]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[5]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[1]/span', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[5]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[2]/span[2]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[5]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[2]/span[2]/span[2]')
# ('/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[7]/div/a', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[7]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[1]/div[2]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[7]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[3]/div/span[2]/span/span[1]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[7]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[1]/span', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[7]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[2]/span[2]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[7]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[2]/span[2]/span[2]')
# ('/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[9]/div/a', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[9]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[1]/div[2]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[9]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[3]/div/span[2]/span/span[1]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[9]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[1]/span', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[9]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[2]/span[2]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[9]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[2]/span[2]/span[2]')
# ('/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[11]/div/a', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[11]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[1]/div[2]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[11]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[3]/div/span[2]/span/span[1]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[11]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[1]/span', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[11]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[1]/span[2]/span[2]', '/html/body/div[2]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[11]/div/div[2]/div[4]/div[1]/div/div/div[2]/div[4]/div[2]/span[2]/span[2]')
