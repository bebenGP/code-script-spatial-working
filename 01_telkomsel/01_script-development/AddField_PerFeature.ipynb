# %%
import arcpy
import os

# %%
workspace = r'D:\Magang ESRI\JOB\Cleansing data\Otomotif\clean_row'
output_folder = r'D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source'

# set the workspace
arcpy.env.workspace = workspace

# get a list of feature class
featureclasslist = arcpy.ListFeatureClasses()

# print feature class
print(featureclasslist)
# Out:
# ['Alva_Motor.shp', 'Aprilia_Motor.shp', 'Aston_Martin_Mobil.shp', 'Audi_Mobil.shp', 'Bajaj_Motor.shp', 'Benelli_Motor.shp', 'Bentley_Mobil.shp', 'BMW_Mobil.shp', 'BMW_Motor.shp', 'Chery_Mobil.shp', 'Cleveland_CycleWerks_Motor.shp', 'Daf_Truck.shp', 'Daihatsu_Mobil.shp', 'Davigo_Motor.shp', 'Dayang_Motor.shp', 'Ducati_Motor.shp', 'Ferrari_Mobil.shp', 'Ford_Mobil.shp', 'Gesits_Motor.shp', 'Happy_Motor_Motor.shp', 'Harley_Davidson_Motor.shp', 'Hino_Truck.shp', 'Honda_Motor.shp', 'Husqvarna_Motor.shp', 'Hyosung_Motor.shp', 'Hyundai_Mobil.shp', 'Infiniti_Mobil.shp', 'Isuzu_Mobil.shp', 'Isuzu_Truck.shp', 'Jaguar_Mobil.shp', 'Jeep_Mobil.shp', 'Jialing_Motor.shp', 'Kawasaki_Motor.shp', 'KIA_Mobil_.shp', 'KTM_Motor.shp', 'Kymco_Motor.shp', 'Lamborghini_Mobil.shp', 'Land_Rover_Mobil.shp', 'Lexus_Mobil.shp', 'Mahindra_Mobil.shp', 'Man_Truck.shp', 'Maserati_Mobil.shp', 'Mazda_Mobil.shp', 'McLaren_Mobil.shp', 'Mercedes_Benz_Truck.shp', 'MG_Mobil.shp', 'Minerva_Motor.shp', 'MINI_Mobil.shp', 'Mitsubishi_Fuso_Truck.shp', 'MV_Agusta_Motor.shp', 'Nissan_Mobil.shp', 'Peugeot_Mobil.shp', 'Porsche_Mobil.shp', 'Renault_Mobil.shp', 'Renault_Truck.shp', 'Rolls_Royce_Mobil.shp', 'Royal_Enfield_Motor.shp', 'Scania_Truck.shp', 'SOIB_Motor.shp', 'Subaru_Mobil.shp', 'Suzuki_Mobil.shp', 'Suzuki_Motor.shp', 'SYM_Motor.shp', 'Tata_Mobil.shp', 'Tata_Truck.shp', 'Tesla_Mobil.shp', 'Triumph_Motor.shp', 'TVS_Motor.shp', 'Vespa_Piaggio_Motor.shp', 'Viar_Motor.shp', 'Volkswagen_Mobil.shp', 'Volvo_Mobil.shp', 'Volvo_Truck.shp', 'Wuling_Mobil.shp', 'Yamaha_Motor.shp']

# %%
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
for fc in featureclasslist:
    try:
        # Create a temporary copy of the feature class
        temp_fc = os.path.join(output_folder, "temp_" + os.path.basename(fc))
        arcpy.CopyFeatures_management(fc, temp_fc)

        # Get a list of fields in the feature class
        field_list = [field.name for field in arcpy.ListFields(temp_fc)]

        # Add tags field if it doesn't exist
        if "tags" not in field_list:
            arcpy.AddField_management(temp_fc, "tags", "TEXT", "", "", 100)
            print("Field 'tags' added to " + temp_fc)
        else:
            print("Field 'tags' already exists in " + temp_fc)
        
        # Add source field if it doesn't exist
        if "source" not in field_list:
            arcpy.AddField_management(temp_fc, "source", "TEXT", "", "", 100)
            print("Field 'source' added to " + temp_fc)
        else:
            print("Field 'source' already exists in " + temp_fc)

        # Check if tags field is empty
        tags_value = arcpy.da.SearchCursor(temp_fc, "tags").next()[0]
        if not tags_value:
            tags_value = input("Enter the value for the 'tags' field in " + temp_fc + ": ")
            arcpy.CalculateField_management(temp_fc, "tags", "'" + tags_value + "'", "PYTHON")
            print("Field 'tags' filled in " + temp_fc)
        else:
            print("Field 'tags' already has a value in " + temp_fc)

        # Check if source field is empty
        source_value = arcpy.da.SearchCursor(temp_fc, "source").next()[0]
        if not source_value:
            source_value = input("Enter the value for the 'source' field in " + temp_fc + ": ")
            arcpy.CalculateField_management(temp_fc, "source", "'" + source_value + "'", "PYTHON")
            print("Field 'source' filled in " + temp_fc)
        else:
            print("Field 'source' already has a value in " + temp_fc)

        # Check if tags or source values need to be edited
        if tags_value or source_value:
            user_choice = input("Do you want to edit the 'tags' and 'source' fields in " + temp_fc + "? (Y/N): ")
            if user_choice.lower() == "y":
                tags_value = input("Enter the new value for the 'tags' field in " + temp_fc + ": ")
                arcpy.CalculateField_management(temp_fc, "tags", "'" + tags_value + "'", "PYTHON")
                source_value = input("Enter the new value for the 'source' field in " + temp_fc + ": ")
                arcpy.CalculateField_management(temp_fc, "source", "'" + source_value + "'", "PYTHON")
                print("Field 'tags' and 'source' edited in " + temp_fc)

        # Copy the feature class to the output folder
        output_feature_class = os.path.join(output_folder, os.path.basename(fc))
        arcpy.CopyFeatures_management(temp_fc, output_feature_class)

        print("Feature class " + fc + " processed successfully.")

        # Delete the temporary copy of the feature class
        arcpy.Delete_management(temp_fc)

    except arcpy.ExecuteError as e:
        print("An error occurred while processing " + fc + ": " + str(e))
# Out:
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Alva_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Alva_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Alva_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Alva_Motor.shp
# Feature class Alva_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Aprilia_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Aprilia_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Aprilia_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Aprilia_Motor.shp
# Feature class Aprilia_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Aston_Martin_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Aston_Martin_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Aston_Martin_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Aston_Martin_Mobil.shp
# Feature class Aston_Martin_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Audi_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Audi_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Audi_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Audi_Mobil.shp
# Feature class Audi_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Bajaj_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Bajaj_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Bajaj_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Bajaj_Motor.shp
# Feature class Bajaj_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Benelli_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Benelli_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Benelli_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Benelli_Motor.shp
# Feature class Benelli_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Bentley_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Bentley_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Bentley_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Bentley_Mobil.shp
# Feature class Bentley_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_BMW_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_BMW_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_BMW_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_BMW_Mobil.shp
# Feature class BMW_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_BMW_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_BMW_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_BMW_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_BMW_Motor.shp
# Feature class BMW_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Chery_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Chery_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Chery_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Chery_Mobil.shp
# Feature class Chery_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Cleveland_CycleWerks_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Cleveland_CycleWerks_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Cleveland_CycleWerks_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Cleveland_CycleWerks_Motor.shp
# Feature class Cleveland_CycleWerks_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Daf_Truck.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Daf_Truck.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Daf_Truck.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Daf_Truck.shp
# Feature class Daf_Truck.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Daihatsu_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Daihatsu_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Daihatsu_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_
Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Minerva_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Minerva_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Minerva_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Minerva_Motor.shp
# Feature class Minerva_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_MINI_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_MINI_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_MINI_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_MINI_Mobil.shp
# Feature class MINI_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Mitsubishi_Fuso_Truck.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Mitsubishi_Fuso_Truck.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Mitsubishi_Fuso_Truck.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Mitsubishi_Fuso_Truck.shp
# Feature class Mitsubishi_Fuso_Truck.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_MV_Agusta_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_MV_Agusta_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_MV_Agusta_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_MV_Agusta_Motor.shp
# Feature class MV_Agusta_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Nissan_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Nissan_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Nissan_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Nissan_Mobil.shp
# Feature class Nissan_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Peugeot_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Peugeot_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Peugeot_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Peugeot_Mobil.shp
# Feature class Peugeot_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Porsche_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Porsche_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Porsche_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Porsche_Mobil.shp
# Feature class Porsche_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Renault_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Renault_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Renault_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Renault_Mobil.shp
# Feature class Renault_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Renault_Truck.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Renault_Truck.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Renault_Truck.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Renault_Truck.shp
# Feature class Renault_Truck.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Rolls_Royce_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Rolls_Royce_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Rolls_Royce_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Rolls_Royce_Mobil.shp
# Feature class Rolls_Royce_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Royal_Enfield_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Royal_Enfield_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Royal_Enfield_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Royal_Enfield_Motor.shp
# Feature class Royal_Enfield_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Scania_Truck.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Scania_Truck.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Scania_Truck.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Scania_Truck.shp
# Feature class Scania_Truck.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_SOIB_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_SOIB_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_SOIB_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_SOIB_Motor.shp
# Feature class SOIB_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Subaru_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Subaru_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Subaru_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Subaru_Mobil.shp
# Feature class Subaru_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Suzuki_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Suzuki_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Suzuki_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Suzuki_Mobil.shp
# Feature class Suzuki_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Suzuki_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Suzuki_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Suzuki_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Suzuki_Motor.shp
# Feature class Suzuki_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_SYM_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_SYM_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_SYM_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_SYM_Motor.shp
# Feature class SYM_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tata_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tata_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tata_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tata_Mobil.shp
# Feature class Tata_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tata_Truck.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tata_Truck.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tata_Truck.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tata_Truck.shp
# Feature class Tata_Truck.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tesla_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tesla_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tesla_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Tesla_Mobil.shp
# Feature class Tesla_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Triumph_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Triumph_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Triumph_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Triumph_Motor.shp
# Feature class Triumph_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_TVS_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_TVS_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_TVS_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_TVS_Motor.shp
# Feature class TVS_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Vespa_Piaggio_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Vespa_Piaggio_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Vespa_Piaggio_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Vespa_Piaggio_Motor.shp
# Feature class Vespa_Piaggio_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Viar_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Viar_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Viar_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Viar_Motor.shp
# Feature class Viar_Motor.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volkswagen_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volkswagen_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volkswagen_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volkswagen_Mobil.shp
# Feature class Volkswagen_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volvo_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volvo_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volvo_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volvo_Mobil.shp
# Feature class Volvo_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volvo_Truck.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volvo_Truck.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volvo_Truck.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Volvo_Truck.shp
# Feature class Volvo_Truck.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Wuling_Mobil.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Wuling_Mobil.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Wuling_Mobil.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Wuling_Mobil.shp
# Feature class Wuling_Mobil.shp processed successfully.
# Field 'tags' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Yamaha_Motor.shp
# Field 'source' added to D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Yamaha_Motor.shp
# Field 'tags' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Yamaha_Motor.shp
# Field 'source' filled in D:\Magang ESRI\JOB\Cleansing data\Otomotif\add_tags_source\temp_Yamaha_Motor.shp
# Feature class Yamaha_Motor.shp processed successfully.
